# %%
R.<w,x,y,z>=QQ[]
p=#insert prime
f(w,x,y,z)=# insert equation of hypersurfaces
f1(w,x,y,z)=derivative(f,w)
f2(w,x,y,z)=derivative(f,x)
f3(w,x,y,z)=derivative(f,y)
f4(w,x,y,z)=derivative(f,z)
J = R.ideal([f1, f2, f3,f4])
q=f(w^(p),x^(p),y^(p),z^(p))-f^(p)
#input all basis elements here- 5 is given here as an example
g1=#first basis element
g2=#second basis element
g3=#third basis element
g4=#fourth basis element
g5=#fifth basis element

#we define multiplication by the w derivative of f, x derivative of f, ....
def Multiplication1(list_in1):
    ImPartialw=[]
    for poly in list_in1:
        Result1= expand(poly*f1(w,x,y,z))
        ImPartialw.append(Result1)
    return ImPartialw


def Multiplication2(list_in2):
    ImPartialx=[]
    for poly in list_in2:
        Result2=expand(poly*f2(w,x,y,z))
        ImPartialx.append(Result2)
    return ImPartialx


def Multiplication3(list_in3):
    ImPartialy=[]
    for poly in list_in3:
        Result3=expand(poly*f3(w,x,y,z))
        ImPartialy.append(Result3)
    return ImPartialy


def Multiplication4(list_in4):
    ImPartialz=[]
    for poly in list_in4:
        Result4=expand(poly*f4(w,x,y,z))
        ImPartialz.append(Result4)
    return ImPartialz

#We define a function that allows us to append rows to a matrix
def insert_row(Matrix,k,row):
    return matrix(Matrix.rows()[:k]+[row]+Matrix.rows()[k:])

#We define the matrix representing df wedge from 3 forms to 4 forms
def A(h,m,n):
    k1=binomial(4+m-1,m)
    k2=binomial(4+n-1,n)
    degree1 = m; [R.monomial(*[x-1 for x in c]) for c in Compositions(4+degree1, length=4)]

    degree2= n; [R.monomial(*[x-1 for x in c]) for c in Compositions(4+degree2, length=4)]
    List1=[R.monomial(*[x-1 for x in c]) for c in Compositions(4+degree1, length=4)]
    List2=[R.monomial(*[x-1 for x in c]) for c in Compositions(4+degree2, length=4)]
    
    CoefficientwList=[]
    for poly in Multiplication1(List1):
        for mono in List2:
            Resultw=poly.coefficient(mono)
            CoefficientwList.append(Resultw)


    CoefficientxList=[]
    for poly in Multiplication2(List1):
        for mono in List2:
            Resultx=poly.coefficient(mono)
            CoefficientxList.append(Resultx)


    CoefficientyList=[]
    for poly in Multiplication3(List1):
        for mono in List2:
            Resulty=poly.coefficient(mono)
            CoefficientyList.append(Resulty)


    CoefficientzList=[]
    for poly in Multiplication4(List1):
        for mono in List2:
            Resultz=poly.coefficient(mono)
            CoefficientzList.append(Resultz)

    def Separation1(list_in11):
        DivCoefficientfwList=[]
        x=1
        while x<k1+1:
            DivCoefficientfwList.append(list_in11[(x-1)*k2:k2*x])
            x += 1
        return DivCoefficientfwList

    def Separation2(list_in22):
        DivCoefficientfxList=[]
        x=1
        while x<k1+1:
            DivCoefficientfxList.append(list_in22[(x-1)*k2:k2*x])
            x += 1
        return DivCoefficientfxList

    def Separation3(list_in33):
        DivCoefficientfyList=[]
        x=1
        while x<k1+1:
            DivCoefficientfyList.append(list_in33[(x-1)*k2:k2*x])
            x += 1
        return DivCoefficientfyList

    def Separation4(list_in44):
        DivCoefficientfzList=[]
        x=1
        while x<k1+1:
            DivCoefficientfzList.append(list_in44[(x-1)*k2:k2*x])
            x += 1
        return DivCoefficientfzList

    Separation1NfwList=[]
    j1=0
    while j1<k1:
        ResultN1=[-1*P for P in Separation1(CoefficientwList)[j1]]
        j1 +=1
        Separation1NfwList.append(ResultN1)


    Separation2NfxList=[]
    j2=0
    while j2<k1:
        ResultN2=[-1*P for P in Separation2(CoefficientxList)[j2]]
        j2 +=1
        Separation2NfxList.append(ResultN2)


    Separation3NfyList=[]
    j3=0
    while j3<k1:
        ResultN3=[-1*P for P in Separation3(CoefficientyList)[j3]]
        j3 +=1
        Separation3NfyList.append(ResultN3)


    Separation4NfzList=[]
    j4=0
    while j4<k1:
        ResultN4=[-1*P for P in Separation4(CoefficientzList)[j4]]
        j4 +=1
        Separation4NfzList.append(ResultN4)


    #ordering in domain goes all monomials dwdxdy, "" dwdxdz, "" dwdydz, ""dxdydz
    #ordering in range is clear, all monomials dwdxdydz

    M=Matrix(QQ, 4*k1,k2)
    i1=0
    while i1<k1:
        M[i1,0:k2]=vector(Separation4(CoefficientzList)[i1])
        i1 +=1

    i2=0
    while i2<k1:
        M[i2+k1,0:k2]=vector(Separation3NfyList[i2])
        i2 +=1

    i3=0
    while i3<k1:
        M[i3+2*k1,0:k2]=vector(Separation2(CoefficientxList)[i3])
        i3 +=1

    i4=0
    while i4<k1:
        M[i4+3*k1,0:k2]=vector(Separation1NfwList[i4])
        i4 +=1
    return M
#we define the matrix for df wedge from 2 forms to 3 forms
def B(h,m,n):
    k1=binomial(4+m-1,m)
    k2=binomial(4+n-1,n)
    degree1 = m; [R.monomial(*[x-1 for x in c]) for c in Compositions(4+degree1, length=4)]

    degree2= n; [R.monomial(*[x-1 for x in c]) for c in Compositions(4+degree2, length=4)]
    List1=[R.monomial(*[x-1 for x in c]) for c in Compositions(4+degree1, length=4)]
    List2=[R.monomial(*[x-1 for x in c]) for c in Compositions(4+degree2, length=4)]
    



    CoefficientwList=[]
    for poly in Multiplication1(List1):
        for mono in List2:
            Resultw=poly.coefficient(mono)
            CoefficientwList.append(Resultw)


    CoefficientxList=[]
    for poly in Multiplication2(List1):
        for mono in List2:
            Resultx=poly.coefficient(mono)
            CoefficientxList.append(Resultx)


    CoefficientyList=[]
    for poly in Multiplication3(List1):
        for mono in List2:
            Resulty=poly.coefficient(mono)
            CoefficientyList.append(Resulty)


    CoefficientzList=[]
    for poly in Multiplication4(List1):
        for mono in List2:
            Resultz=poly.coefficient(mono)
            CoefficientzList.append(Resultz)

    def Separation1(list_in11):
        DivCoefficientfwList=[]
        x=1
        while x<k1+1:
            DivCoefficientfwList.append(list_in11[(x-1)*k2:k2*x])
            x += 1
        return DivCoefficientfwList

    def Separation2(list_in22):
        DivCoefficientfxList=[]
        x=1
        while x<k1+1:
            DivCoefficientfxList.append(list_in22[(x-1)*k2:k2*x])
            x += 1
        return DivCoefficientfxList

    def Separation3(list_in33):
        DivCoefficientfyList=[]
        x=1
        while x<k1+1:
            DivCoefficientfyList.append(list_in33[(x-1)*k2:k2*x])
            x += 1
        return DivCoefficientfyList

    def Separation4(list_in44):
        DivCoefficientfzList=[]
        x=1
        while x<k1+1:
            DivCoefficientfzList.append(list_in44[(x-1)*k2:k2*x])
            x += 1
        return DivCoefficientfzList

    Separation1NfwList=[]
    j1=0
    while j1<k1:
        ResultN1=[-1*P for P in Separation1(CoefficientwList)[j1]]
        j1 +=1
        Separation1NfwList.append(ResultN1)


    Separation2NfxList=[]
    j2=0
    while j2<k1:
        ResultN2=[-1*P for P in Separation2(CoefficientxList)[j2]]
        j2 +=1
        Separation2NfxList.append(ResultN2)


    Separation3NfyList=[]
    j3=0
    while j3<k1:
        ResultN3=[-1*P for P in Separation3(CoefficientyList)[j3]]
        j3 +=1
        Separation3NfyList.append(ResultN3)


    Separation4NfzList=[]
    j4=0
    while j4<k1:
        ResultN4=[-1*P for P in Separation4(CoefficientzList)[j4]]
        j4 +=1
        Separation4NfzList.append(ResultN4)
        
    M2=Matrix(QQ, 6*k1,4*k2)
    i1=0
    while i1<k1:
        M2[i1,0:k2]=vector(Separation3(CoefficientyList)[i1])
        M2[i1,k2:2*k2]=vector(Separation4(CoefficientzList)[i1])
        i1 +=1

    i2=0
    while i2<k1:
        M2[i2+k1,0:k2]=vector(Separation2NfxList[i2])
        M2[i2+k1,2*k2:3*k2]=vector(Separation4(CoefficientzList)[i2])
        i2 +=1

    i3=0
    while i3<k1:
        M2[i3+2*k1,k2:2*k2]=vector(Separation2NfxList[i3])
        M2[i3+2*k1,2*k2:3*k2]=vector(Separation3NfyList[i3])
        i3 +=1

    i4=0
    while i4<k1:
        M2[i4+3*k1,0:k2]=vector(Separation1(CoefficientwList)[i4])
        M2[i4+3*k1,3*k2:4*k2]=vector(Separation4(CoefficientzList)[i4])
        i4 +=1

    i5=0
    while i5<k1:
        M2[i5+4*k1,k2:2*k2]=vector(Separation1(CoefficientwList)[i5])
        M2[i5+4*k1,3*k2:4*k2]=vector(Separation3NfyList[i5])
        i5 +=1

    i6=0
    while i6<k1:
        M2[i6+5*k1,2*k2:3*k2]=vector(Separation1(CoefficientwList)[i6])
        M2[i6+5*k1,3*k2:4*k2]=vector(Separation2(CoefficientxList)[i6])
        i6 +=1
    return M2

#we define a function that makes monomials with exponential powers not divisible by n go away and keeps those that are
#this is necessary from formula of the action of inverse Frobenius
def restrict_exponents_to_multiples(h, n):
    return h.parent()({ee: c for ee, c in h.dict().items()
                                 if all(e % n == 0 for e in ee)})
#input differential operators here, in this case, we only need to define 1 as the rest are easy to type


#define operators
#define Coefficient Solver as in Cubic Case


#We make a list for each basis element

ListforConstants=[]
ListforaBasis1=[]
ListforaBasis2=[]
ListforaBasis3=[]
ListforaBasis4=[]
ListforaBasis5=[]
ListforaBasis6=[]
#up to number of basis elements

List=[ListforaBasis1,ListforaBasis2,ListforaBasis3,ListforaBasis4,ListforaBasis5,ListforaBasis6,...#up to number of basis element]
ListB=[g1,g2,g3,g4,g5,..]

# %% [markdown]
# len(List[0])

# %%
#action of Frobenius + reduction of basis element for k=3
h=f^(p-2)*w*x*y*z*List[#insert basis element number-1, for example, if first basis element, put 0]*(q^(3))
h=h.polynomial(QQ)
h1=restrict_exponents_to_multiples(h,p)
if h1==0:
    pass

else: 
    
    h1(w,x,y,z)=h1
    h1=h1(w^(1/p),x^(1/p),y^(1/p),z^(1/p)).polynomial(QQ)
    g=p^(3)*x*y*w*z
    g=g.polynomial(QQ)
    h1=h1//g
    R.<w,x,y,z>=QQ[]
    f=#insert equation of hypersurface
    f1=derivative(f,w)
    f2=derivative(f,x)
    f3=derivative(f,y)
    f4=derivative(f,z)
    J = R.ideal([f1, f2, f3,f4])
    jacobian(f, (w,x,y,z))
    #insert the de rham of the subdigonal and apply the Coefficient Solver function
    q1, q2, q3, q4 = h2.lift(J)
    q1=1/3 * q1(w,x,y,z).derivative(w)
    q2=1/3 *q2(w,x,y,z).derivative(x)
    q3=1/3 *q3(w,x,y,z).derivative(y)
    q4=1/3*q4(w,x,y,z).derivative(z)
    h1=q1+q2+q3+q4
    #insert the de rham of the subdigonal and apply the Coefficient Solver function
    q1, q2, q3, q4 = h2.lift(J)
    q1=1/2 * q1(w,x,y,z).derivative(w)
    q2=1/2 *q2(w,x,y,z).derivative(x)
    q3=1/2 *q3(w,x,y,z).derivative(y)
    q4=1/2*q4(w,x,y,z).derivative(z)
    List[0].append(q1+q2+q3+q4)
    
#action of Frobenius + reduction of basis element for k=2
h=f^(p-2)*w*x*y*z*List[#insert basis element number-1, for example, if first basis element, put 0]*(q^(2))
h=h.polynomial(QQ)
h1=restrict_exponents_to_multiples(h,p)
if h1==0:
    pass

else: 
    
    h1(w,x,y,z)=h1
    h1=h1(w^(1/p),x^(1/p),y^(1/p),z^(1/p)).polynomial(QQ)
    g=p^(3)*x*y*w*z
    g=g.polynomial(QQ)
    h1=h1//g
    R.<w,x,y,z>=QQ[]
    f=#insert equation of hypersurface
    f1=derivative(f,w)
    f2=derivative(f,x)
    f3=derivative(f,y)
    f4=derivative(f,z)
    J = R.ideal([f1, f2, f3,f4])
    jacobian(f, (w,x,y,z))
    #insert the de rham of the subdigonal and apply the Coefficient Solver function
    q1, q2, q3, q4 = h2.lift(J)
    q1=1/2 * q1(w,x,y,z).derivative(w)
    q2=1/2 *q2(w,x,y,z).derivative(x)
    q3=1/2 *q3(w,x,y,z).derivative(y)
    q4=1/2*q4(w,x,y,z).derivative(z)
    List[0].append(q1+q2+q3+q4)
#action of Frobenius for k=1
h=f^(p-2)*w*x*y*z*List[#insert basis element number-1, for example, if first basis element, put 0]*q
h=h.polynomial(QQ)
h1=restrict_exponents_to_multiples(h,p)
if h1==0:
    pass
else:
    h1(w,x,y,z)=h1
    h1=h1(w^(1/p),x^(1/p),y^(1/p),z^(1/p)).polynomial(QQ)
    g=p^(3)*x*y*w*z
    g=g.polynomial(QQ)
    h1=h1//g
    List[0].append(h1)

#action of Frobenius for k=0
h=f^(p-2)*w*x*y*z*List[#insert basis element number-1, for example, if first basis element, put 0]
h=h.polynomial(QQ)
h1=restrict_exponents_to_multiples(h,p)
if h1==0:
    ListforConstants.append(h1)
else:
    h1(w,x,y,z)=h1
    h1=h1(w^(1/p),x^(1/p),y^(1/p),z^(1/p)).polynomial(QQ)
    g=p^(3)*x*y*w*z
    g=g.polynomial(QQ)
    h1=h1//g
    ListforConstants.append(h1)

len(List[#insert basis element number-1, for example, if first basis element, put 0]), List[#insert basis element number-1, for example, if first basis element, put 0], ListforConstants

# %%
#action of Frobenius + reduction on for the basis element 1
R.<w,x,y,z>=QQ[]
p=11
f(w,x,y,z)= #insert equation of hypersurface
f1(w,x,y,z)=derivative(f,w)
f2(w,x,y,z)=derivative(f,x)
f3(w,x,y,z)=derivative(f,y)
f4(w,x,y,z)=derivative(f,z)
q=f(w^(p),x^(p),y^(p),z^(p))-f^(p)
h=f^(p-1)*w*x*y*z*(q^(3))
h=h.polynomial(QQ)
h1=restrict_exponents_to_multiples(h,p)
if h1==0:
    pass

else: 

    h1(w,x,y,z)=h1
    h1=h1(w^(1/p),x^(1/p),y^(1/p),z^(1/p)).polynomial(QQ)
    g=p^(3)*x*y*w*z
    g=g.polynomial(QQ)
    h1=h1//g
    R.<w,x,y,z>=QQ[]
    f=#input equation of hypersurface
    f1=derivative(f,w)
    f2=derivative(f,x)
    f3=derivative(f,y)
    f4=derivative(f,z)
    J = R.ideal([f1, f2, f3,f4])
    jacobian(f, (w,x,y,z))
    #insert the de rham of the subdiagonal and apply Coefficient Solver function
    q1, q2, q3, q4 = h2.lift(J)
    q1=1/3 * q1(w,x,y,z).derivative(w)
    q2=1/3 *q2(w,x,y,z).derivative(x)
    q3=1/3 *q3(w,x,y,z).derivative(y)
    q4=1/3*q4(w,x,y,z).derivative(z)
    h1=q1+q2+q3+q4
    #insert the de rham of the subdiagonal and apply Coefficient Solver function
    q1, q2, q3, q4 = h2.lift(J)
    q1=1/2 * q1(w,x,y,z).derivative(w)
    q2=1/2 *q2(w,x,y,z).derivative(x)
    q3=1/2 *q3(w,x,y,z).derivative(y)
    q4=1/2*q4(w,x,y,z).derivative(z)
    #last part of List.append(q1+q2+q3+q4)
#action of Frobenius + reduction on 15th basis element for k=2 (image is degree 8)
R.<w,x,y,z>=QQ[]
p=11
f(w,x,y,z)=#insert equation of hypersurface
f1(w,x,y,z)=derivative(f,w)
f2(w,x,y,z)=derivative(f,x)
f3(w,x,y,z)=derivative(f,y)
f4(w,x,y,z)=derivative(f,z)
q=f(w^(p),x^(p),y^(p),z^(p))-f^(p)
h=f^(p-1)*w*x*y*z*(q^(2))
h=h.polynomial(QQ)
h1=restrict_exponents_to_multiples(h,p)
if h1==0:
    pass

else: 

    h1(w,x,y,z)=h1
    h1=h1(w^(1/p),x^(1/p),y^(1/p),z^(1/p)).polynomial(QQ)
    g=p^(3)*x*y*w*z
    g=g.polynomial(QQ)
    h1=h1//g
    R.<w,x,y,z>=QQ[]
    f=#input equation of hypersurface
    f1=derivative(f,w)
    f2=derivative(f,x)
    f3=derivative(f,y)
    f4=derivative(f,z)
    J = R.ideal([f1, f2, f3,f4])
    jacobian(f, (w,x,y,z))
    #insert the de rham of the subdiagonal and apply Coefficient Solver function
    q1, q2, q3, q4 = h2.lift(J)
    q1=1/2 * q1(w,x,y,z).derivative(w)
    q2=1/2 *q2(w,x,y,z).derivative(x)
    q3=1/2 *q3(w,x,y,z).derivative(y)
    q4=1/2*q4(w,x,y,z).derivative(z)
    List[0].append(q1+q2+q3+q4)
#action of Frobenius on 15th basis element for k=1
R.<w,x,y,z>=QQ[]
p=11
f(w,x,y,z)=#insert equation of hypersurface
f1(w,x,y,z)=derivative(f,w)
f2(w,x,y,z)=derivative(f,x)
f3(w,x,y,z)=derivative(f,y)
f4(w,x,y,z)=derivative(f,z)
q=f(w^(p),x^(p),y^(p),z^(p))-f^(p)
h=f^(p-1)*w*x*y*z*(q)
h=h.polynomial(QQ)
h1=restrict_exponents_to_multiples(h,p)
if h1==0:
    pass

else: 

    h1(w,x,y,z)=h1
    h1=h1(w^(1/p),x^(1/p),y^(1/p),z^(1/p)).polynomial(QQ)
    g=p^(3)*x*y*w*z
    g=g.polynomial(QQ)
    h1=h1//g
    List[0].append(h1)

#action of Frobenius on 15th basis element for k=0
R.<w,x,y,z>=QQ[]
p=11
f(w,x,y,z)=#insert equation of hypersurface
f1(w,x,y,z)=derivative(f,w)
f2(w,x,y,z)=derivative(f,x)
f3(w,x,y,z)=derivative(f,y)
f4(w,x,y,z)=derivative(f,z)
q=f(w^(p),x^(p),y^(p),z^(p))-f^(p)
h=f^(p-1)*w*x*y*z
h=h.polynomial(QQ)
h1=restrict_exponents_to_multiples(h,p)
if h1==0:
    pass

else: 

    h1(w,x,y,z)=h1
    h1=h1(w^(1/p),x^(1/p),y^(1/p),z^(1/p)).polynomial(QQ)
    g=p^(3)*x*y*w*z
    g=g.polynomial(QQ)
    h1=h1//g
    ListforConstants.append(h1)

len(List[#insert basis element number-1, for example, if first basis element, put 0]), List[#insert basis element number-1, for example, if first basis element, put 0], ListforConstants

# %%
#Expressing the reduced monomials as linear combination of basis elements
ListofMonomials2=[R.monomial(*[x-1 for x in c]) for c in Compositions(4+4, length=4)]
ListofLists=[]
BasisforE2=[g1,g2,g3,g4,g5,...] #exclude 1 if 1 is basis element
I=matrix.identity(len(ListofMonomials2))
ListofLists.append(I[ListofMonomials2.index(g1)])#type out the vector for basis elements of monomials in degree 2
ListofLists.append(I[ListofMonomials2.index(g2)])
ListofLists.append(I[ListofMonomials2.index(g3)])
ListofLists.append(I[ListofMonomials2.index(g4)])
ListofLists.append(I[ListofMonomials2.index(g5)])
#continue on for the basis elements that are not possibly one



#note there is no k=0 term as this leads to the power of f being 1

#Vector for de rham

R.<w,x,y,z>=QQ[]
M=A(f,1,4)
Range=M.image().basis()

degree2=4  #degree of  monomials in basis of top diagonal
List2=[R.monomial(*[x-1 for x in c]) for c in Compositions(4+degree2, length=4)]
I=matrix.identity(len(List2))

QuotientNot=[]
Quotient=[]
MatrixforRange=Matrix(QQ,Range)
for i in range(len(List2)):
    MatrixforRange=insert_row(MatrixforRange,0,I[i])
    if MatrixforRange.rank()==len(QuotientNot)+len(Range)+1:
            QuotientNot.append(I[i])
    else:
            Quotient.append(I[i])
    
BasisNumbering=[]
BasisCount=sum(QuotientNot[i] for i in [0..len(QuotientNot)-1])
i=0
while i <len(List2):
    Multiplication=BasisCount[i]*List2[i]
    BasisNumbering.append(Multiplication)
    i+=1   


NumberofZeros=BasisNumbering.count(0)

i=0
while i<NumberofZeros:
    BasisNumbering.remove(0)
    i+=1
BasisNumbering
BasisNumberingForm=[]
U = Manifold(4, 'U')
X.<w,x,y,z> = U.chart()
for poly in BasisNumbering:
    Resultform=U.diff_form(4,'Resultform')
    Resultform[0,1,2,3]=poly
    BasisNumberingForm.append(Resultform)



NewMatrix=M
i=0
while i<len(QuotientNot):
    NewMatrix=insert_row(NewMatrix,0,QuotientNot[len(QuotientNot)-i-1])
    i+=1

CoefficientsforSpan=[]
i=0
while i<len(Quotient):
    newterm=NewMatrix.solve_left(Quotient[i])
    CoefficientsforSpan.append(newterm)
    i+=1

CoefficientsforSpan2=[]
for newterm in CoefficientsforSpan:
    i=0
    while i<len(QuotientNot):
        CoefficientsforSpan2.append(newterm[i])
        i+=1

CoefficientsforSpan3=[]
i=0
while i<len(Quotient):
    CoefficientsforSpan3.append(sum(a*b for (a,b) in zip(BasisNumbering, CoefficientsforSpan2[len(BasisNumbering)*i:len(BasisNumbering)*(i+1)])))
    i+=1

NonBasisNumbering=[]
for poly in List2:
    if poly in BasisNumbering:
        pass 
    else:
        NonBasisNumbering.append(poly)

ExpressQuotient=[]

i=0
while i<len(NonBasisNumbering):
    ExpressQuotient.append(NonBasisNumbering[i]-CoefficientsforSpan3[i])
    i+=1


M1=A(f,5,8)
M2=B(f,2,5)
Kernel=M1.kernel().basis()
Range=M2.image().basis()

QuotientNot1=[]
MatrixforRange1=Matrix(QQ,Range)
for i in range(len(Kernel)):
    MatrixforRange1=insert_row(MatrixforRange1,0,Kernel[i])
    if MatrixforRange1.rank()==len(QuotientNot1)+len(Range)+1:
            QuotientNot1.append(Kernel[i])


List2=[R.monomial(*[x-1 for x in c]) for c in Compositions(4+5, length=4)]
Listforbottom1=[]

for poly in List2:
    Resultform=U.diff_form(3,'Resultform')
    Resultform[0,1,2]=poly
    Listforbottom1.append(Resultform)

for poly in List2:
    Resultform=U.diff_form(3,'Resultform')
    Resultform[0,1,3]=poly
    Listforbottom1.append(Resultform)

for poly in List2:
    Resultform=U.diff_form(3,'Resultform')
    Resultform[0,2,3]=poly
    Listforbottom1.append(Resultform)
    
for poly in List2:
    Resultform=U.diff_form(3,'Resultform')
    Resultform[1,2,3]=poly
    Listforbottom1.append(Resultform)

BasisforSecondtoTop=[sum(x*y for (x,y) in zip(v, Listforbottom1)) for v in QuotientNot1]
ListforDerivative=[]
for form in BasisforSecondtoTop:
    Resultform=form.exterior_derivative()
    ListforDerivative.append(Resultform)

ListforExpanded=[]
i=0
while i<len(ListforDerivative):
    Polynomial=expand(ListforDerivative[i][0,1,2,3].expr())
    ListforExpanded.append(Polynomial)
    i+=1
    
ListforExpanded1=[]
for poly in ListforExpanded:
    i=0
    while i<len(NonBasisNumbering):
        poly=poly-poly.coefficient(NonBasisNumbering[i])*ExpressQuotient[i]
        i+=1
    ListforExpanded1.append(poly)

ListforDerivative1=[]
for poly in ListforExpanded1:
    Resultform=U.diff_form(4,'Resultform')
    Resultform[0,1,2,3]=poly
    ListforDerivative1.append(Resultform)
        
        
Listforderham = []
for poly in ListforExpanded1:
    Listforderham.append([poly.coefficient(a) for a in ListofMonomials2])

#this gives the vector for action of de rham on th
#vectorforderham end#

#below should be appending up to the global Milnor number)
#this is the basis for the image of df wedge
ListofLists.append(A(f,1,4)[0])
ListofLists.append(A(f,1,4)[1])
ListofLists.append(A(f,1,4)[2])
ListofLists.append(A(f,1,4)[3])
ListofLists.append(A(f,1,4)[4])
ListofLists.append(A(f,1,4)[5])
ListofLists.append(A(f,1,4)[6])
ListofLists.append(A(f,1,4)[7])
ListofLists.append(A(f,1,4)[8])
ListofLists.append(A(f,1,4)[9])
ListofLists.append(A(f,1,4)[10])
ListofLists.append(A(f,1,4)[11])
ListofLists.append(A(f,1,4)[12])
ListofLists.append(A(f,1,4)[13])
ListofLists.append(A(f,1,4)[14])
ListofLists.append(A(f,1,4)[15])

#note this was calculated using the E2 page calculation
#insert the ListofLists.append(all the Listforderham rows)







#################################################
M=Matrix(ListofLists)

# %%
M.rank()

# %%
CL=[]


L=[(#sum up elements in the list).coefficient(a) for a in ListofMonomials2]
v1=M.solve_left(vector(L))

#make new list and append(v1[0]*BasisforE2[0])
#similarly, on the new list, append (v1[1]*BasisforE2[1])
#append up to length of BasisforE2
#Example is NewList.append((v1[0]*BasisforE2[0])
        #NewList.append((v1[1]*BasisforE2[1]))
        #NewList.append((v1[2]*BasisforE2[2]))
        #so on so forth

U = Manifold(4, 'U')
X.<w,x,y,z> = U.chart()
h1 = U.diff_form(3, 'h1')
h2 = U.diff_form(3, 'h2')
h3 = U.diff_form(3, 'h3')
h4 = U.diff_form(3, 'h4')
h5 = U.diff_form(3, 'h5')
h6 = U.diff_form(3, 'h6')
h7 = U.diff_form(3, 'h7')
h8 = U.diff_form(3, 'h8')
h9 = U.diff_form(3, 'h9')
h10 = U.diff_form(3, 'h10')
h11 = U.diff_form(3, 'h11')
h12 = U.diff_form(3, 'h12')
h13 = U.diff_form(3, 'h13')
h14 = U.diff_form(3, 'h14')
h15 = U.diff_form(3, 'h15')
h16 = U.diff_form(3, 'h16')
h1[0,1,2]=v1[5]*w
h2[0,1,2]=v1[6]*x
h3[0,1,2]=v1[7]*y
h4[0,1,2]=v1[8]*z
h5[0,1,3]=v1[9]*w
h6[0,1,3]=v1[10]*x
h7[0,1,3]=v1[11]*y
h8[0,1,3]=v1[12]*z
h9[0,2,3]=v1[13]*w
h10[0,2,3]=v1[14]*x
h11[0,2,3]=v1[15]*y
h12[0,2,3]=v1[16]*z
h13[1,2,3]=v1[17]*w
h14[1,2,3]=v1[18]*x
h15[1,2,3]=v1[19]*y
h16[1,2,3]=v1[20]*z
h=(h1+h2+h3+h4+h5+h6+h7+h8+h9+h10+h11+h12+h13+h14+h15+h16).exterior_derivative()
h=(h[0,1,2,3].expr())
#NewList.append(h+ListforConstants[0])
#make List called Lrow
Lrow.append(#NewList[0].coefficient(g1))
Lrow.append(#NewList[1].coefficient(g2))
...#so on so forth

Lrow[0]

# %%
#once you have done this for all basis elements, compute the matrix and characteristic polynomial as in Frobenius redction for Cubic code
