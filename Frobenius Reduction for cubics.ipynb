# %%
R.<w,x,y,z>=QQ[]
p=#insert prime
f(w,x,y,z)=#insert equation of hypersurface
f1(w,x,y,z)=derivative(f,w)
f2(w,x,y,z)=derivative(f,x)
f3(w,x,y,z)=derivative(f,y)
f4(w,x,y,z)=derivative(f,z)
J = R.ideal([f1, f2, f3,f4])
q=f(w^(p),x^(p),y^(p),z^(p))-f^(p)
#input all basis elements here- 2 is set as an example
g1=#basis element one
g2=#basis element two






#we define multiplication by the w derivative of f, x derivative of f, ....
def Multiplication1(list_in1):
    ImPartialw=[]
    for poly in list_in1:
        Result1= expand(poly*f1(w,x,y,z))
        ImPartialw.append(Result1)
    return ImPartialw


def Multiplication2(list_in2):
    ImPartialx=[]
    for poly in list_in2:
        Result2=expand(poly*f2(w,x,y,z))
        ImPartialx.append(Result2)
    return ImPartialx


def Multiplication3(list_in3):
    ImPartialy=[]
    for poly in list_in3:
        Result3=expand(poly*f3(w,x,y,z))
        ImPartialy.append(Result3)
    return ImPartialy


def Multiplication4(list_in4):
    ImPartialz=[]
    for poly in list_in4:
        Result4=expand(poly*f4(w,x,y,z))
        ImPartialz.append(Result4)
    return ImPartialz

#We define a function that allows us to append rows to a matrix
def insert_row(Matrix,k,row):
    return matrix(Matrix.rows()[:k]+[row]+Matrix.rows()[k:])

#We define the matrix representing df wedge from 3 forms to 4 forms
def A(h,m,n):
    k1=binomial(4+m-1,m)
    k2=binomial(4+n-1,n)
    degree1 = m; [R.monomial(*[x-1 for x in c]) for c in Compositions(4+degree1, length=4)]

    degree2= n; [R.monomial(*[x-1 for x in c]) for c in Compositions(4+degree2, length=4)]
    List1=[R.monomial(*[x-1 for x in c]) for c in Compositions(4+degree1, length=4)]
    List2=[R.monomial(*[x-1 for x in c]) for c in Compositions(4+degree2, length=4)]
    
    CoefficientwList=[]
    for poly in Multiplication1(List1):
        for mono in List2:
            Resultw=poly.coefficient(mono)
            CoefficientwList.append(Resultw)


    CoefficientxList=[]
    for poly in Multiplication2(List1):
        for mono in List2:
            Resultx=poly.coefficient(mono)
            CoefficientxList.append(Resultx)


    CoefficientyList=[]
    for poly in Multiplication3(List1):
        for mono in List2:
            Resulty=poly.coefficient(mono)
            CoefficientyList.append(Resulty)


    CoefficientzList=[]
    for poly in Multiplication4(List1):
        for mono in List2:
            Resultz=poly.coefficient(mono)
            CoefficientzList.append(Resultz)

    def Separation1(list_in11):
        DivCoefficientfwList=[]
        x=1
        while x<k1+1:
            DivCoefficientfwList.append(list_in11[(x-1)*k2:k2*x])
            x += 1
        return DivCoefficientfwList

    def Separation2(list_in22):
        DivCoefficientfxList=[]
        x=1
        while x<k1+1:
            DivCoefficientfxList.append(list_in22[(x-1)*k2:k2*x])
            x += 1
        return DivCoefficientfxList

    def Separation3(list_in33):
        DivCoefficientfyList=[]
        x=1
        while x<k1+1:
            DivCoefficientfyList.append(list_in33[(x-1)*k2:k2*x])
            x += 1
        return DivCoefficientfyList

    def Separation4(list_in44):
        DivCoefficientfzList=[]
        x=1
        while x<k1+1:
            DivCoefficientfzList.append(list_in44[(x-1)*k2:k2*x])
            x += 1
        return DivCoefficientfzList

    Separation1NfwList=[]
    j1=0
    while j1<k1:
        ResultN1=[-1*P for P in Separation1(CoefficientwList)[j1]]
        j1 +=1
        Separation1NfwList.append(ResultN1)


    Separation2NfxList=[]
    j2=0
    while j2<k1:
        ResultN2=[-1*P for P in Separation2(CoefficientxList)[j2]]
        j2 +=1
        Separation2NfxList.append(ResultN2)


    Separation3NfyList=[]
    j3=0
    while j3<k1:
        ResultN3=[-1*P for P in Separation3(CoefficientyList)[j3]]
        j3 +=1
        Separation3NfyList.append(ResultN3)


    Separation4NfzList=[]
    j4=0
    while j4<k1:
        ResultN4=[-1*P for P in Separation4(CoefficientzList)[j4]]
        j4 +=1
        Separation4NfzList.append(ResultN4)


    #ordering in domain goes all monomials dwdxdy, "" dwdxdz, "" dwdydz, ""dxdydz
    #ordering in range is clear, all monomials dwdxdydz

    M=Matrix(QQ, 4*k1,k2)
    i1=0
    while i1<k1:
        M[i1,0:k2]=vector(Separation4(CoefficientzList)[i1])
        i1 +=1

    i2=0
    while i2<k1:
        M[i2+k1,0:k2]=vector(Separation3NfyList[i2])
        i2 +=1

    i3=0
    while i3<k1:
        M[i3+2*k1,0:k2]=vector(Separation2(CoefficientxList)[i3])
        i3 +=1

    i4=0
    while i4<k1:
        M[i4+3*k1,0:k2]=vector(Separation1NfwList[i4])
        i4 +=1
    return M
#we define the matrix for df wedge from 2 forms to 3 forms
def B(h,m,n):
    k1=binomial(4+m-1,m)
    k2=binomial(4+n-1,n)
    degree1 = m; [R.monomial(*[x-1 for x in c]) for c in Compositions(4+degree1, length=4)]

    degree2= n; [R.monomial(*[x-1 for x in c]) for c in Compositions(4+degree2, length=4)]
    List1=[R.monomial(*[x-1 for x in c]) for c in Compositions(4+degree1, length=4)]
    List2=[R.monomial(*[x-1 for x in c]) for c in Compositions(4+degree2, length=4)]
    



    CoefficientwList=[]
    for poly in Multiplication1(List1):
        for mono in List2:
            Resultw=poly.coefficient(mono)
            CoefficientwList.append(Resultw)


    CoefficientxList=[]
    for poly in Multiplication2(List1):
        for mono in List2:
            Resultx=poly.coefficient(mono)
            CoefficientxList.append(Resultx)


    CoefficientyList=[]
    for poly in Multiplication3(List1):
        for mono in List2:
            Resulty=poly.coefficient(mono)
            CoefficientyList.append(Resulty)


    CoefficientzList=[]
    for poly in Multiplication4(List1):
        for mono in List2:
            Resultz=poly.coefficient(mono)
            CoefficientzList.append(Resultz)

    def Separation1(list_in11):
        DivCoefficientfwList=[]
        x=1
        while x<k1+1:
            DivCoefficientfwList.append(list_in11[(x-1)*k2:k2*x])
            x += 1
        return DivCoefficientfwList

    def Separation2(list_in22):
        DivCoefficientfxList=[]
        x=1
        while x<k1+1:
            DivCoefficientfxList.append(list_in22[(x-1)*k2:k2*x])
            x += 1
        return DivCoefficientfxList

    def Separation3(list_in33):
        DivCoefficientfyList=[]
        x=1
        while x<k1+1:
            DivCoefficientfyList.append(list_in33[(x-1)*k2:k2*x])
            x += 1
        return DivCoefficientfyList

    def Separation4(list_in44):
        DivCoefficientfzList=[]
        x=1
        while x<k1+1:
            DivCoefficientfzList.append(list_in44[(x-1)*k2:k2*x])
            x += 1
        return DivCoefficientfzList

    Separation1NfwList=[]
    j1=0
    while j1<k1:
        ResultN1=[-1*P for P in Separation1(CoefficientwList)[j1]]
        j1 +=1
        Separation1NfwList.append(ResultN1)


    Separation2NfxList=[]
    j2=0
    while j2<k1:
        ResultN2=[-1*P for P in Separation2(CoefficientxList)[j2]]
        j2 +=1
        Separation2NfxList.append(ResultN2)


    Separation3NfyList=[]
    j3=0
    while j3<k1:
        ResultN3=[-1*P for P in Separation3(CoefficientyList)[j3]]
        j3 +=1
        Separation3NfyList.append(ResultN3)


    Separation4NfzList=[]
    j4=0
    while j4<k1:
        ResultN4=[-1*P for P in Separation4(CoefficientzList)[j4]]
        j4 +=1
        Separation4NfzList.append(ResultN4)
        
    M2=Matrix(QQ, 6*k1,4*k2)
    i1=0
    while i1<k1:
        M2[i1,0:k2]=vector(Separation3(CoefficientyList)[i1])
        M2[i1,k2:2*k2]=vector(Separation4(CoefficientzList)[i1])
        i1 +=1

    i2=0
    while i2<k1:
        M2[i2+k1,0:k2]=vector(Separation2NfxList[i2])
        M2[i2+k1,2*k2:3*k2]=vector(Separation4(CoefficientzList)[i2])
        i2 +=1

    i3=0
    while i3<k1:
        M2[i3+2*k1,k2:2*k2]=vector(Separation2NfxList[i3])
        M2[i3+2*k1,2*k2:3*k2]=vector(Separation3NfyList[i3])
        i3 +=1

    i4=0
    while i4<k1:
        M2[i4+3*k1,0:k2]=vector(Separation1(CoefficientwList)[i4])
        M2[i4+3*k1,3*k2:4*k2]=vector(Separation4(CoefficientzList)[i4])
        i4 +=1

    i5=0
    while i5<k1:
        M2[i5+4*k1,k2:2*k2]=vector(Separation1(CoefficientwList)[i5])
        M2[i5+4*k1,3*k2:4*k2]=vector(Separation3NfyList[i5])
        i5 +=1

    i6=0
    while i6<k1:
        M2[i6+5*k1,2*k2:3*k2]=vector(Separation1(CoefficientwList)[i6])
        M2[i6+5*k1,3*k2:4*k2]=vector(Separation2(CoefficientxList)[i6])
        i6 +=1
    return M2

#we define a function that makes monomials with exponential powers not divisible by n go away and keeps those that are
#this is necessary from formula of the action of inverse Frobenius
def restrict_exponents_to_multiples(h, n):
    return h.parent()({ee: c for ee, c in h.dict().items()
                                 if all(e % n == 0 for e in ee)})
#input differential operators here, in this case, we only need to define 1 as the rest are easy to type


#input the differential operators equivalent to Jacobian-an example is given below, adjust as necessary
def CoefficientsSolver(fcn1, fcn2, fcn3, fcn4, fcn5):
    a, b, c, d = SR.var('a, b, c, d')
    eqn1= fcn1(0,0,0,1)-a*fcn2(0,0,0,1)-b*fcn3(0,0,0,1)-c*fcn4(0,0,0,1)-d*fcn5(0,0,0,1)==0
    eqn2= fcn1(0,1,0,0)-a*fcn2(0,1,0,0)-b*fcn3(0,1,0,0)-c*fcn4(0,1,0,0)-d*fcn5(0,1,0,0)==0
    eqn3= derivative(fcn1(w,x,y,z),y)(0,1,0,0)-a*derivative(fcn2(w,x,y,z),y)(0,1,0,0)-b*derivative(fcn3(w,x,y,z),y)(0,1,0,0)-c*derivative(fcn4(w,x,y,z),y)(0,1,0,0)-d*derivative(fcn5(w,x,y,z),y)(0,1,0,0)==0
    eqn4= derivative(fcn1(w,x,y,z),y)(0,0,0,1)-a*derivative(fcn2(w,x,y,z),y)(0,0,0,1)-b*derivative(fcn3(w,x,y,z),y)(0,0,0,1)-c*derivative(fcn4(w,x,y,z),y)(0,0,0,1)-d*derivative(fcn5(w,x,y,z),y)(0,0,0,1)==0
    sol = solve([eqn1, eqn2, eqn3, eqn4], a, b, c, d, solution_dict=True)[0]
    Poly=fcn1 -sol[a]*fcn2 - sol[b]*fcn3 - sol[c]*fcn4 - sol[d]*fcn5
    return Poly



#We make a list for each basis element
ListforaBasis1=[]
ListforaBasis2=[]

#action of Frobenius+reduction on first basis element for k=4 (image is degree 11)
h=f^(p-2)*g1*w*x*y*z*(q^(4))
h=h.polynomial(QQ)
h1=restrict_exponents_to_multiples(h,p)
if h1==0:
    pass

else: 
    
    h1(w,x,y,z)=h1
    h1=h1(w^(1/p),x^(1/p),y^(1/p),z^(1/p)).polynomial(QQ)
    g=p^(3)*x*y*w*z
    g=g.polynomial(QQ)
    h1=h1//g
    R.<w,x,y,z>=QQ[]
    f=#insert equation of hypersurface
    f1=derivative(f,w)
    f2=derivative(f,x)
    f3=derivative(f,y)
    f4=derivative(f,z)
    J = R.ideal([f1, f2, f3,f4])
    jacobian(f, (w,x,y,z))
    v1=-6*w^3*x^8 - 103/9*w*x^10 - 40/3*x^10*y - 30*w^3*x^7*z - 184/3*w*x^9*z - 72*x^9*y*z - 60*w^3*x^6*z^2 - 135*w*x^8*z^2 - 160*x^8*y*z^2 - 60*w^3*x^5*z^3 - 1400/9*w*x^7*z^3 - 560/3*x^7*y*z^3 - 30*w^3*x^4*z^4 - 295/3*w*x^6*z^4 - 120*x^6*y*z^4 - 6*w^3*x^3*z^5 - 32*w*x^5*z^5 - 40*x^5*y*z^5 - 37/9*w*x^4*z^6 - 16/3*x^4*y*z^6
    v2=-6*w^2*x^9 - 11*x^11 - 12*x^9*y^2 - 30*w^2*x^8*z - 60*x^10*z - 60*x^8*y^2*z - 60*w^2*x^7*z^2 - 135*x^9*z^2 - 120*x^7*y^2*z^2 - 60*w^2*x^6*z^3 - 160*x^8*z^3 - 120*x^6*y^2*z^3 - 30*w^2*x^5*z^4 - 105*x^7*z^4 - 60*x^5*y^2*z^4 - 6*w^2*x^4*z^5 - 36*x^6*z^5 - 12*x^4*y^2*z^5 - 5*x^5*z^6
    v3=2*x^6*y*z^4 - 30*x^4*y*z^6 - 80*x^3*y*z^7 - 90*x^2*y*z^8 - 48*x*y*z^9 - 10*y*z^10
    v4=x^6*z^5 - 6*x^5*z^6 - 45*x^4*z^7 - 100*x^3*z^8 - 105*x^2*z^9 - 54*x*z^10 - 11*z^11
    h2=CoefficientsSolver(h1,v1,v2,v3,v4).polynomial(QQ)
    q1, q2, q3, q4 = h2.lift(J)
    q1=1/4 * q1(w,x,y,z).derivative(w)
    q2=1/4 *q2(w,x,y,z).derivative(x)
    q3=1/4 *q3(w,x,y,z).derivative(y)
    q4=1/4*q4(w,x,y,z).derivative(z)
    h1=q1+q2+q3+q4
    v1=-3*w^3*x^5 - 70/9*w*x^7 - 28/3*x^7*y - 6*w^3*x^4*z - 59/3*w*x^6*z - 24*x^6*y*z - 3*w^3*x^3*z^2 - 16*w*x^5*z^2 - 20*x^5*y*z^2 - 37/9*w*x^4*z^3 - 16/3*x^4*y*z^3
    v2=-3*w^2*x^6 - 8*x^8 - 6*x^6*y^2 - 6*w^2*x^5*z - 21*x^7*z - 12*x^5*y^2*z - 3*w^2*x^4*z^2 - 18*x^6*z^2 - 6*x^4*y^2*z^2 - 5*x^5*z^3
    v3= -x^3*y*z^4 - 9*x^2*y*z^5 - 15*x*y*z^6 - 7*y*z^7
    v4= -2*x^3*z^5 - 12*x^2*z^6 - 18*x*z^7 - 8*z^8
    h2=CoefficientsSolver(h1,v1,v2,v3,v4).polynomial(QQ)
    q1, q2, q3, q4 = h2.lift(J)
    q1=1/3 * q1(w,x,y,z).derivative(w)
    q2=1/3 *q2(w,x,y,z).derivative(x)
    q3=1/3 *q3(w,x,y,z).derivative(y)
    q4=1/3*q4(w,x,y,z).derivative(z)
    h1=q1+q2+q3+q4
    v1=-37/9*w*x^4 - 16/3*x^4*y
    v2=-5*x^5
    v3= -4*y*z^4
    v4= -5*z^5
    h2=CoefficientsSolver(h1,v1,v2,v3,v4).polynomial(QQ)
    q1, q2, q3, q4 = h2.lift(J)
    q1=1/2 * q1(w,x,y,z).derivative(w)
    q2=1/2 *q2(w,x,y,z).derivative(x)
    q3=1/2 *q3(w,x,y,z).derivative(y)
    q4=1/2*q4(w,x,y,z).derivative(z)
    ListforaBasis1.append(q1+q2+q3+q4)
    
#action of Frobenius + reduction on first basis element for k=3 (image is degree 8)
h=f^(p-2)*g1*w*x*y*z*(q^(3))
h=h.polynomial(QQ)
h1=restrict_exponents_to_multiples(h,p)
if h1==0:
    pass

else: 
    
    h1(w,x,y,z)=h1
    h1=h1(w^(1/p),x^(1/p),y^(1/p),z^(1/p)).polynomial(QQ)
    g=p^(3)*x*y*w*z
    g=g.polynomial(QQ)
    h1=h1//g
    R.<w,x,y,z>=QQ[]
    f=#insert equation of hypersurface
    f1=derivative(f,w)
    f2=derivative(f,x)
    f3=derivative(f,y)
    f4=derivative(f,z)
    J = R.ideal([f1, f2, f3,f4])
    jacobian(f, (w,x,y,z))
    v1=-3*w^3*x^5 - 70/9*w*x^7 - 28/3*x^7*y - 6*w^3*x^4*z - 59/3*w*x^6*z - 24*x^6*y*z - 3*w^3*x^3*z^2 - 16*w*x^5*z^2 - 20*x^5*y*z^2 - 37/9*w*x^4*z^3 - 16/3*x^4*y*z^3
    v2=-3*w^2*x^6 - 8*x^8 - 6*x^6*y^2 - 6*w^2*x^5*z - 21*x^7*z - 12*x^5*y^2*z - 3*w^2*x^4*z^2 - 18*x^6*z^2 - 6*x^4*y^2*z^2 - 5*x^5*z^3
    v3= -x^3*y*z^4 - 9*x^2*y*z^5 - 15*x*y*z^6 - 7*y*z^7
    v4= -2*x^3*z^5 - 12*x^2*z^6 - 18*x*z^7 - 8*z^8
    h2=CoefficientsSolver(h1,v1,v2,v3,v4).polynomial(QQ)
    q1, q2, q3, q4 = h2.lift(J)
    q1=1/3 * q1(w,x,y,z).derivative(w)
    q2=1/3 *q2(w,x,y,z).derivative(x)
    q3=1/3 *q3(w,x,y,z).derivative(y)
    q4=1/3*q4(w,x,y,z).derivative(z)
    h1=q1+q2+q3+q4
    v1=-37/9*w*x^4 - 16/3*x^4*y
    v2=-5*x^5
    v3= -4*y*z^4
    v4= -5*z^5
    h2=CoefficientsSolver(h1,v1,v2,v3,v4).polynomial(QQ)
    q1, q2, q3, q4 = h2.lift(J)
    q1=1/2 * q1(w,x,y,z).derivative(w)
    q2=1/2 *q2(w,x,y,z).derivative(x)
    q3=1/2 *q3(w,x,y,z).derivative(y)
    q4=1/2*q4(w,x,y,z).derivative(z)
    ListforaBasis1.append(q1+q2+q3+q4)
    
#action of Frobenius + reduction on first basis element for k=2 (image is degree 5)
h=f^(p-2)*g1*w*x*y*z*(q^(2))
h=h.polynomial(QQ)
h1=restrict_exponents_to_multiples(h,p)
if h1==0:
    pass

else: 
    
    h1(w,x,y,z)=h1
    h1=h1(w^(1/p),x^(1/p),y^(1/p),z^(1/p)).polynomial(QQ)
    g=p^(3)*x*y*w*z
    g=g.polynomial(QQ)
    h1=h1//g
    R.<w,x,y,z>=QQ[]
    f=#insert equation of hypersurface
    f1=derivative(f,w)
    f2=derivative(f,x)
    f3=derivative(f,y)
    f4=derivative(f,z)
    J = R.ideal([f1, f2, f3,f4])
    jacobian(f, (w,x,y,z))
    v1=-37/9*w*x^4 - 16/3*x^4*y
    v2=-5*x^5
    v3= -4*y*z^4
    v4= -5*z^5
    h2=CoefficientsSolver(h1,v1,v2,v3,v4).polynomial(QQ)
    q1, q2, q3, q4 = h2.lift(J)
    q1=1/2 * q1(w,x,y,z).derivative(w)
    q2=1/2 *q2(w,x,y,z).derivative(x)
    q3=1/2 *q3(w,x,y,z).derivative(y)
    q4=1/2*q4(w,x,y,z).derivative(z)
    ListforaBasis1.append(q1+q2+q3+q4)
#action of Frobenius on first basis element for k=1
h=f^(p-2)*g1*w*x*y*z*q
h=h.polynomial(QQ)
h1=restrict_exponents_to_multiples(h,p)
if h1==0:
    pass
else:
    h1(w,x,y,z)=h1
    h1=h1(w^(1/p),x^(1/p),y^(1/p),z^(1/p)).polynomial(QQ)
    g=p^(3)*x*y*w*z
    g=g.polynomial(QQ)
    h1=h1//g
    ListforaBasis1.append(h1)

ListforaBasis1

# %%
#action of Frobenius+ reduction on second basis element for k=4
h=f^(p-2)*g2*w*x*y*z*(q^(4))
h=h.polynomial(QQ)
h1=restrict_exponents_to_multiples(h,p)
if h1==0:
    pass

else: 
    
    h1(w,x,y,z)=h1
    h1=h1(w^(1/p),x^(1/p),y^(1/p),z^(1/p)).polynomial(QQ)
    g=p^(3)*x*y*w*z
    g=g.polynomial(QQ)
    h1=h1//g
    R.<w,x,y,z>=QQ[]
    f=#insert equation of hypersurface
    f1=derivative(f,w)
    f2=derivative(f,x)
    f3=derivative(f,y)
    f4=derivative(f,z)
    J = R.ideal([f1, f2, f3,f4])
    jacobian(f, (w,x,y,z))
    v1=-6*w^3*x^8 - 103/9*w*x^10 - 40/3*x^10*y - 30*w^3*x^7*z - 184/3*w*x^9*z - 72*x^9*y*z - 60*w^3*x^6*z^2 - 135*w*x^8*z^2 - 160*x^8*y*z^2 - 60*w^3*x^5*z^3 - 1400/9*w*x^7*z^3 - 560/3*x^7*y*z^3 - 30*w^3*x^4*z^4 - 295/3*w*x^6*z^4 - 120*x^6*y*z^4 - 6*w^3*x^3*z^5 - 32*w*x^5*z^5 - 40*x^5*y*z^5 - 37/9*w*x^4*z^6 - 16/3*x^4*y*z^6
    v2=-6*w^2*x^9 - 11*x^11 - 12*x^9*y^2 - 30*w^2*x^8*z - 60*x^10*z - 60*x^8*y^2*z - 60*w^2*x^7*z^2 - 135*x^9*z^2 - 120*x^7*y^2*z^2 - 60*w^2*x^6*z^3 - 160*x^8*z^3 - 120*x^6*y^2*z^3 - 30*w^2*x^5*z^4 - 105*x^7*z^4 - 60*x^5*y^2*z^4 - 6*w^2*x^4*z^5 - 36*x^6*z^5 - 12*x^4*y^2*z^5 - 5*x^5*z^6
    v3=2*x^6*y*z^4 - 30*x^4*y*z^6 - 80*x^3*y*z^7 - 90*x^2*y*z^8 - 48*x*y*z^9 - 10*y*z^10
    v4=x^6*z^5 - 6*x^5*z^6 - 45*x^4*z^7 - 100*x^3*z^8 - 105*x^2*z^9 - 54*x*z^10 - 11*z^11
    h2=CoefficientsSolver(h1,v1,v2,v3,v4).polynomial(QQ)
    q1, q2, q3, q4 = h2.lift(J)
    q1=1/4 * q1(w,x,y,z).derivative(w)
    q2=1/4 *q2(w,x,y,z).derivative(x)
    q3=1/4 *q3(w,x,y,z).derivative(y)
    q4=1/4*q4(w,x,y,z).derivative(z)
    h1=q1+q2+q3+q4
    v1=-3*w^3*x^5 - 70/9*w*x^7 - 28/3*x^7*y - 6*w^3*x^4*z - 59/3*w*x^6*z - 24*x^6*y*z - 3*w^3*x^3*z^2 - 16*w*x^5*z^2 - 20*x^5*y*z^2 - 37/9*w*x^4*z^3 - 16/3*x^4*y*z^3
    v2=-3*w^2*x^6 - 8*x^8 - 6*x^6*y^2 - 6*w^2*x^5*z - 21*x^7*z - 12*x^5*y^2*z - 3*w^2*x^4*z^2 - 18*x^6*z^2 - 6*x^4*y^2*z^2 - 5*x^5*z^3
    v3= -x^3*y*z^4 - 9*x^2*y*z^5 - 15*x*y*z^6 - 7*y*z^7
    v4= -2*x^3*z^5 - 12*x^2*z^6 - 18*x*z^7 - 8*z^8
    h2=CoefficientsSolver(h1,v1,v2,v3,v4).polynomial(QQ)
    q1, q2, q3, q4 = h2.lift(J)
    q1=1/3 * q1(w,x,y,z).derivative(w)
    q2=1/3 *q2(w,x,y,z).derivative(x)
    q3=1/3 *q3(w,x,y,z).derivative(y)
    q4=1/3*q4(w,x,y,z).derivative(z)
    h1=q1+q2+q3+q4
    v1=-37/9*w*x^4 - 16/3*x^4*y
    v2=-5*x^5
    v3= -4*y*z^4
    v4= -5*z^5
    h2=CoefficientsSolver(h1,v1,v2,v3,v4).polynomial(QQ)
    q1, q2, q3, q4 = h2.lift(J)
    q1=1/2 * q1(w,x,y,z).derivative(w)
    q2=1/2 *q2(w,x,y,z).derivative(x)
    q3=1/2 *q3(w,x,y,z).derivative(y)
    q4=1/2*q4(w,x,y,z).derivative(z)
    ListforaBasis2.append(q1+q2+q3+q4)
    




#action of Frobenius+ reduction on second basis element for k=3
h=f^(p-2)*g2*w*x*y*z*(q^(3))
h=h.polynomial(QQ)
h1=restrict_exponents_to_multiples(h,p)
if h1==0:
    pass

else: 
    
    h1(w,x,y,z)=h1
    h1=h1(w^(1/p),x^(1/p),y^(1/p),z^(1/p)).polynomial(QQ)
    g=p^(3)*x*y*w*z
    g=g.polynomial(QQ)
    h1=h1//g
    R.<w,x,y,z>=QQ[]
    f=insert equation of hypersurface
    f1=derivative(f,w)
    f2=derivative(f,x)
    f3=derivative(f,y)
    f4=derivative(f,z)
    J = R.ideal([f1, f2, f3,f4])
    jacobian(f, (w,x,y,z))
    v1=-3*w^3*x^5 - 70/9*w*x^7 - 28/3*x^7*y - 6*w^3*x^4*z - 59/3*w*x^6*z - 24*x^6*y*z - 3*w^3*x^3*z^2 - 16*w*x^5*z^2 - 20*x^5*y*z^2 - 37/9*w*x^4*z^3 - 16/3*x^4*y*z^3
    v2=-3*w^2*x^6 - 8*x^8 - 6*x^6*y^2 - 6*w^2*x^5*z - 21*x^7*z - 12*x^5*y^2*z - 3*w^2*x^4*z^2 - 18*x^6*z^2 - 6*x^4*y^2*z^2 - 5*x^5*z^3
    v3= -x^3*y*z^4 - 9*x^2*y*z^5 - 15*x*y*z^6 - 7*y*z^7
    v4= -2*x^3*z^5 - 12*x^2*z^6 - 18*x*z^7 - 8*z^8
    h2=CoefficientsSolver(h1,v1,v2,v3,v4).polynomial(QQ)
    q1, q2, q3, q4 = h2.lift(J)
    q1=1/3 * q1(w,x,y,z).derivative(w)
    q2=1/3 *q2(w,x,y,z).derivative(x)
    q3=1/3 *q3(w,x,y,z).derivative(y)
    q4=1/3*q4(w,x,y,z).derivative(z)
    h1=q1+q2+q3+q4
    v1=-37/9*w*x^4 - 16/3*x^4*y
    v2=-5*x^5
    v3= -4*y*z^4
    v4= -5*z^5
    h2=CoefficientsSolver(h1,v1,v2,v3,v4).polynomial(QQ)
    q1, q2, q3, q4 = h2.lift(J)
    q1=1/2 * q1(w,x,y,z).derivative(w)
    q2=1/2 *q2(w,x,y,z).derivative(x)
    q3=1/2 *q3(w,x,y,z).derivative(y)
    q4=1/2*q4(w,x,y,z).derivative(z)
    ListforaBasis2.append(q1+q2+q3+q4)
    
#action of Frobenius + reduction on second basis element for k=2 (image is degree 5)
h=f^(p-2)*g2*w*x*y*z*(q^(2))
h=h.polynomial(QQ)
h1=restrict_exponents_to_multiples(h,p)
if h1==0:
    pass

else: 
    
    h1(w,x,y,z)=h1
    h1=h1(w^(1/p),x^(1/p),y^(1/p),z^(1/p)).polynomial(QQ)
    g=p^(3)*x*y*w*z
    g=g.polynomial(QQ)
    h1=h1//g
    R.<w,x,y,z>=QQ[]
    f=#insert equation of hypersurface
    f1=derivative(f,w)
    f2=derivative(f,x)
    f3=derivative(f,y)
    f4=derivative(f,z)
    J = R.ideal([f1, f2, f3,f4])
    jacobian(f, (w,x,y,z))
    v1=-37/9*w*x^4 - 16/3*x^4*y
    v2=-5*x^5
    v3= -4*y*z^4
    v4= -5*z^5
    h2=CoefficientsSolver(h1,v1,v2,v3,v4).polynomial(QQ)
    q1, q2, q3, q4 = h2.lift(J)
    q1=1/2 * q1(w,x,y,z).derivative(w)
    q2=1/2 *q2(w,x,y,z).derivative(x)
    q3=1/2 *q3(w,x,y,z).derivative(y)
    q4=1/2*q4(w,x,y,z).derivative(z)
    ListforaBasis2.append(q1+q2+q3+q4)
#action of Frobenius on second basis element for k=1
h=f^(p-2)*g2*w*x*y*z*q
h=h.polynomial(QQ)
h1=restrict_exponents_to_multiples(h,p)
if h1==0:
    pass
else:
    h1(w,x,y,z)=h1
    h1=h1(w^(1/p),x^(1/p),y^(1/p),z^(1/p)).polynomial(QQ)
    g=p^(3)*x*y*w*z
    g=g.polynomial(QQ)
    h1=h1//g
    ListforaBasis2.append(h1)


ListforaBasis1, ListforaBasis2

# %%
#Expressing the reduced monomials as linear combination of basis elements
ListofMonomials2=[R.monomial(*[x-1 for x in c]) for c in Compositions(4+2, length=4)]
ListofLists=[]
BasisforE2=[g1,g2]
I=matrix.identity(len(ListofMonomials2))
ListofLists.append(I[ListofMonomials2.index(g1)])
ListofLists.append(I[ListofMonomials2.index(g2)])


#note there is no k=0 term as this leads to the power of f being 1

#Vector for de rham

R.<w,x,y,z>=QQ[]
M=A(f,0,2)
Range=M.image().basis()

degree2=2  #degree of  monomials in basis of top diagonal
List2=[R.monomial(*[x-1 for x in c]) for c in Compositions(4+degree2, length=4)]
I=matrix.identity(len(List2))

QuotientNot=[]
Quotient=[]
MatrixforRange=Matrix(QQ,Range)
for i in range(len(List2)):
    MatrixforRange=insert_row(MatrixforRange,0,I[i])
    if MatrixforRange.rank()==len(QuotientNot)+len(Range)+1:
            QuotientNot.append(I[i])
    else:
            Quotient.append(I[i])
    
BasisNumbering=[]
BasisCount=sum(QuotientNot[i] for i in [0..len(QuotientNot)-1])
i=0
while i <len(List2):
    Multiplication=BasisCount[i]*List2[i]
    BasisNumbering.append(Multiplication)
    i+=1   


NumberofZeros=BasisNumbering.count(0)

i=0
while i<NumberofZeros:
    BasisNumbering.remove(0)
    i+=1
BasisNumbering
BasisNumberingForm=[]
U = Manifold(4, 'U')
X.<w,x,y,z> = U.chart()
for poly in BasisNumbering:
    Resultform=U.diff_form(4,'Resultform')
    Resultform[0,1,2,3]=poly
    BasisNumberingForm.append(Resultform)



NewMatrix=M
i=0
while i<len(QuotientNot):
    NewMatrix=insert_row(NewMatrix,0,QuotientNot[len(QuotientNot)-i-1])
    i+=1

CoefficientsforSpan=[]
i=0
while i<len(Quotient):
    newterm=NewMatrix.solve_left(Quotient[i])
    CoefficientsforSpan.append(newterm)
    i+=1

CoefficientsforSpan2=[]
for newterm in CoefficientsforSpan:
    i=0
    while i<len(QuotientNot):
        CoefficientsforSpan2.append(newterm[i])
        i+=1

CoefficientsforSpan3=[]
i=0
while i<len(Quotient):
    CoefficientsforSpan3.append(sum(a*b for (a,b) in zip(BasisNumbering, CoefficientsforSpan2[len(BasisNumbering)*i:len(BasisNumbering)*(i+1)])))
    i+=1

NonBasisNumbering=[]
for poly in List2:
    if poly in BasisNumbering:
        pass 
    else:
        NonBasisNumbering.append(poly)

ExpressQuotient=[]

i=0
while i<len(NonBasisNumbering):
    ExpressQuotient.append(NonBasisNumbering[i]-CoefficientsforSpan3[i])
    i+=1


M1=A(f,3,5)
M2=B(f,1,3)
Kernel=M1.kernel().basis()
Range=M2.image().basis()

QuotientNot1=[]
MatrixforRange1=Matrix(QQ,Range)
for i in range(len(Kernel)):
    MatrixforRange1=insert_row(MatrixforRange1,0,Kernel[i])
    if MatrixforRange1.rank()==len(QuotientNot1)+len(Range)+1:
            QuotientNot1.append(Kernel[i])


List2=[R.monomial(*[x-1 for x in c]) for c in Compositions(4+3, length=4)]
Listforbottom1=[]

for poly in List2:
    Resultform=U.diff_form(3,'Resultform')
    Resultform[0,1,2]=poly
    Listforbottom1.append(Resultform)

for poly in List2:
    Resultform=U.diff_form(3,'Resultform')
    Resultform[0,1,3]=poly
    Listforbottom1.append(Resultform)

for poly in List2:
    Resultform=U.diff_form(3,'Resultform')
    Resultform[0,2,3]=poly
    Listforbottom1.append(Resultform)
    
for poly in List2:
    Resultform=U.diff_form(3,'Resultform')
    Resultform[1,2,3]=poly
    Listforbottom1.append(Resultform)

BasisforSecondtoTop=[sum(x*y for (x,y) in zip(v, Listforbottom1)) for v in QuotientNot1]
ListforDerivative=[]
for form in BasisforSecondtoTop:
    Resultform=form.exterior_derivative()
    ListforDerivative.append(Resultform)
show(LatexExpr('[' + ','.join(latex(f.display()) for f in ListforDerivative) + ']'))
ListforExpanded=[]
i=0
while i<len(ListforDerivative):
    Polynomial=expand(ListforDerivative[i][0,1,2,3].expr())
    ListforExpanded.append(Polynomial)
    i+=1
    
ListforExpanded1=[]
for poly in ListforExpanded:
    i=0
    while i<len(NonBasisNumbering):
        poly=poly-poly.coefficient(NonBasisNumbering[i])*ExpressQuotient[i]
        i+=1
    ListforExpanded1.append(poly)

ListforDerivative1=[]
for poly in ListforExpanded1:
    Resultform=U.diff_form(4,'Resultform')
    Resultform[0,1,2,3]=poly
    ListforDerivative1.append(Resultform)
        
        
Listforderham = []
for poly in ListforExpanded:
    Listforderham.append([poly.coefficient(a) for a in ListofMonomials2])

#this gives the vector for action of de rham on th
#vectorforderham end#

#below should be appending up to the global Milnor number)
#this is the basis for the image of df wedge
ListofLists.append(A(f,1,4)[0])
ListofLists.append(A(f,1,4)[1])
ListofLists.append(A(f,1,4)[2])
ListofLists.append(A(f,1,4)[3])
#note this was calculated using the E2 page calculation, the de rham differential on the subdiagonal
ListofLists.append(Listforderham[0])
ListofLists.append(Listforderham[1])
ListofLists.append(Listforderham[2])
ListofLists.append(Listforderham[3])


#################################################
M=Matrix(ListofLists)
L=[(ListforaBasis1[0]+ListforaBasis1[1]+ListforaBasis1[2]+ListforaBasis1[3]).coefficient(a) for a in ListofMonomials2]
v1=M.solve_left(vector(L))
CoefficientList1=[]
CoefficientList1.append(v1[0]*BasisforE2[0])
CoefficientList1.append(v1[1]*BasisforE2[1])

L=[(ListforaBasis2[0]+ListforaBasis2[1]+ListforaBasis2[2]+ListforaBasis2[3]).coefficient(a) for a in ListofMonomials2]
v1=M.solve_left(vector(L))
CoefficientList2=[]
CoefficientList2.append(v1[0]*BasisforE2[0])
CoefficientList2.append(v1[1]*BasisforE2[1])
#Below are the reduction to linear combination of the basis elements
CoefficientList1, CoefficientList2

# %%
#Finally, we calculate the zeta function
Matrix1=matrix([[#input the first row],[#input 2nd row] ] )
Matrix2=1/p*Matrix1.inverse()
I=matrix.identity(# of basis elements)
K = Qp(p, prec = 10, type = 'capped-rel', print_mode = 'series')
Char1=det(I-x*Matrix2)
Char1.expand()
